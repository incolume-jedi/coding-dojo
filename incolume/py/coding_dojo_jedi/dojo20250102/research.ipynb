# %%
import pandas as pd

# %%
df1 = pd.read_json('report.json')

# %%
df1
# Out:
#                                                      file  \
# 0                       z:acervo-legis/CCIVIL_03/C927.htm
# 1                z:acervo-legis/CCIVIL_03/index-supar.htm
# 2                      z:acervo-legis/CCIVIL_03/index.htm
# 3                  z:acervo-legis/CCIVIL_03/index_AGU.htm
# 4                         z:acervo-legis/CCIVIL_03/pl.htm
# ...                                                   ...
# 240051  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240052  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240053  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240054  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240055  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2019-20...
#
#                                                     items
# 0       [http://legislacao.planalto.gov.br/legisla/leg...
# 1                                                      []
# 2       [https://legislacao.planalto.gov.br/legisla/le...
# ...

# %%
df1.shape
# Out:
# (240056, 2)

# %%
df1.dtypes
# Out:
# file     object
# items    object
# dtype: object

# %%
df1.items
# Out:
# <bound method DataFrame.items of                                                      file  \
# 0                       z:acervo-legis/CCIVIL_03/C927.htm
# 1                z:acervo-legis/CCIVIL_03/index-supar.htm
# 2                      z:acervo-legis/CCIVIL_03/index.htm
# 3                  z:acervo-legis/CCIVIL_03/index_AGU.htm
# 4                         z:acervo-legis/CCIVIL_03/pl.htm
# ...                                                   ...
# 240051  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240052  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240053  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240054  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240055  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2019-20...
#
#                                                     items
# 0       [http://legislacao.planalto.gov.br/legisla/leg...
# 1                                                      []
# 2       [https://legislacao.planalto.gov.br/legisla/le...
# ...

# %%
df1['items'].str.split(',')
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 240051   NaN
# 240052   NaN
# 240053   NaN
# 240054   NaN
# 240055   NaN
# Name: items, Length: 240056, dtype: float64

# %%
df1['items']
# Out:
# 0         [http://legislacao.planalto.gov.br/legisla/leg...
# 1                                                        []
# 2         [https://legislacao.planalto.gov.br/legisla/le...
# 3         [https://legislacao.planalto.gov.br/legisla/le...
# 4                                                        []
#                                 ...
# 240051    [http://www.ilo.org/wcmsp5/groups/public/---as...
# 240052                                                   []
# 240053                                                   []
# 240054                                                   []
# 240055                                                   []
# Name: items, Length: 240056, dtype: object

# %%
df1['items']
# Out:
# 0         [http://legislacao.planalto.gov.br/legisla/leg...
# 1                                                        []
# 2         [https://legislacao.planalto.gov.br/legisla/le...
# 3         [https://legislacao.planalto.gov.br/legisla/le...
# 4                                                        []
#                                 ...
# 240051    [http://www.ilo.org/wcmsp5/groups/public/---as...
# 240052                                                   []
# 240053                                                   []
# 240054                                                   []
# 240055                                                   []
# Name: items, Length: 240056, dtype: object

# %%
df1['items'].astype
# Out:
# <bound method NDFrame.astype of 0         [http://legislacao.planalto.gov.br/legisla/leg...
# 1                                                        []
# 2         [https://legislacao.planalto.gov.br/legisla/le...
# 3         [https://legislacao.planalto.gov.br/legisla/le...
# 4                                                        []
#                                 ...
# 240051    [http://www.ilo.org/wcmsp5/groups/public/---as...
# 240052                                                   []
# 240053                                                   []
# 240054                                                   []
# 240055                                                   []
# Name: items, Length: 240056, dtype: object>

# %%
df1['items'].tolist()
# Out:
# [['http://legislacao.planalto.gov.br/legisla/legislacao.nsf/Viw_Identificacao/lei%2010.406-2002?OpenDocument'],
#  [],
#  ['https://legislacao.planalto.gov.br/legisla/legislacao.nsf/FrmConsultaWeb1?OpenForm',
#   'https://legislacao.planalto.gov.br/cddir/cddir.nsf',
#   'http://www.saj.planalto.gov.br/saj/Boletins.nsf/frmInscricaoWeb?OpenForm'],
#  ['https://legislacao.planalto.gov.br/legisla/legislacao.nsf/FrmConsultaWeb1?OpenForm',
#   'https://legislacao.planalto.gov.br/cddir/cddir.nsf',
#   'http://www.saj.planalto.gov.br/saj/Boletins.nsf/frmInscricaoWeb?OpenForm'],
#  [],
#  ['Ret/Ret-acp-1-65.docx',
#   'http://legislacao.planalto.gov.br/legisla/legislacao.nsf/Viw_Identificacao/ACP%201-1965?OpenDocument'],
#  ['http://legislacao.planalto.gov.br/legisla/legislacao.nsf/Viw_Identificacao/ACP%202-1965?OpenDocument'],
#  ['http://legislacao.planalto.gov.br/legisla/legislacao.nsf/Viw_Identificacao/ACP%203-1965?OpenDocument'],
# ...

# %%
df1['list'] = df1['items'].tolist()

# %%
df1
# Out:
#                                                      file  \
# 0                       z:acervo-legis/CCIVIL_03/C927.htm
# 1                z:acervo-legis/CCIVIL_03/index-supar.htm
# 2                      z:acervo-legis/CCIVIL_03/index.htm
# 3                  z:acervo-legis/CCIVIL_03/index_AGU.htm
# 4                         z:acervo-legis/CCIVIL_03/pl.htm
# ...                                                   ...
# 240051  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240052  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240053  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240054  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240055  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2019-20...
#
#                                                     items  \
# 0       [http://legislacao.planalto.gov.br/legisla/leg...
# 1                                                      []
# 2       [https://legislacao.planalto.gov.br/legisla/le...
# ...

# %%
df1.list
# Out:
# 0         [http://legislacao.planalto.gov.br/legisla/leg...
# 1                                                        []
# 2         [https://legislacao.planalto.gov.br/legisla/le...
# 3         [https://legislacao.planalto.gov.br/legisla/le...
# 4                                                        []
#                                 ...
# 240051    [http://www.ilo.org/wcmsp5/groups/public/---as...
# 240052                                                   []
# 240053                                                   []
# 240054                                                   []
# 240055                                                   []
# Name: list, Length: 240056, dtype: object

# %%
df1.list.apply(lambda x: len([a for a in x if '.doc' in a]))
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 240051    0
# 240052    0
# 240053    0
# 240054    0
# 240055    0
# Name: list, Length: 240056, dtype: int64

# %%
df1['doc'] = df1.list.apply(
    lambda x: len([a for a in x if '.doc' in a.casefold()]),
)

# %%
df1['xls'] = df1.list.apply(
    lambda x: len([a for a in x if '.xls' in a.casefold()]),
)

# %%
df1['nsf'] = df1.list.apply(
    lambda x: len([a for a in x if '.nsf' in a.casefold()]),
)

# %%
df1['rtf'] = df1.list.apply(
    lambda x: len([a for a in x if '.rtf' in a.casefold()]),
)

# %%
df1
# Out:
#                                                      file  \
# 0                       z:acervo-legis/CCIVIL_03/C927.htm
# 1                z:acervo-legis/CCIVIL_03/index-supar.htm
# 2                      z:acervo-legis/CCIVIL_03/index.htm
# 3                  z:acervo-legis/CCIVIL_03/index_AGU.htm
# 4                         z:acervo-legis/CCIVIL_03/pl.htm
# ...                                                   ...
# 240051  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240052  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240053  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240054  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...
# 240055  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2019-20...
#
#                                                     items  \
# 0       [http://legislacao.planalto.gov.br/legisla/leg...
# 1                                                      []
# 2       [https://legislacao.planalto.gov.br/legisla/le...
# ...

# %%
df1.columns
# Out:
# Index(['file', 'items', 'list', 'doc', 'xls', 'nsf', 'rtf'], dtype='object')

# %%
df1[['file', 'doc', 'xls', 'nsf', 'rtf']]
# Out:
#                                                      file  doc  xls  nsf  rtf
# 0                       z:acervo-legis/CCIVIL_03/C927.htm    0    0    1    0
# 1                z:acervo-legis/CCIVIL_03/index-supar.htm    0    0    0    0
# 2                      z:acervo-legis/CCIVIL_03/index.htm    0    0    3    0
# 3                  z:acervo-legis/CCIVIL_03/index_AGU.htm    0    0    3    0
# 4                         z:acervo-legis/CCIVIL_03/pl.htm    0    0    0    0
# ...                                                   ...  ...  ...  ...  ...
# 240051  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...    0    0    0    0
# 240052  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...    0    0    0    0
# 240053  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...    0    0    0    0
# 240054  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2023-20...    0    0    0    0
# 240055  z:acervo-legis/CCIVIL_03/AGU/Pareceres/2019-20...    0    0    0    0
#
# [240056 rows x 5 columns]

# %%
df1[['file', 'doc', 'xls', 'nsf', 'rtf']].to_excel('report.xlsx')
