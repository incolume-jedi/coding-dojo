# %% [markdown]
# # extração de texto do áudio
#
# - originalmente implementado em:
# https://colab.research.google.com/drive/1Y5xMWVB9dJouJmxpCIWy5INJ4k1P_xoZ#scrollTo=WXV9WfKDKjUC

# %% [markdown]
# ## dependências do projeto
# ```bash
# !sudo apt update
# !sudo apt install ffmpeg
# !pip install git+https://github.com/openai/whisper.git
# ```

# %%
from pathlib import Path

# %%
dir()
# Out:
# ['In',
#  'Out',
#  'Path',
#  '_',
#  '_7',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__vsc_ipynb_file__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'fl_audio',
#  'get_ipython',
#  'open',
#  'quit']

# %%
fl_audio = Path('insumos', '17_06_2020 20.34.m4a')

# %%
fl_audio.exists()
# Out:
# False

# %%
# !whisper fl_audio --model medium
# Out:
# /bin/bash: linha 1: whisper: comando não encontrado
