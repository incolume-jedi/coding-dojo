# %% [markdown]
# # extração de texto do áudio
#
# - originalmente implementado em:
# https://colab.research.google.com/drive/1Y5xMWVB9dJouJmxpCIWy5INJ4k1P_xoZ#scrollTo=WXV9WfKDKjUC

# %%
# dependências do projeto
# !sudo apt update && sudo apt install ffmpeg
# !pip install git+https://github.com/openai/whisper.git
# Out:
# [sudo] senha para brito:
# sudo: uma senha é necessária
# ^C
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-h5fh_tpx
# Exception:
# Traceback (most recent call last):
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_internal/cli/base_command.py", line 143, in main
#     status = self.run(options, args)
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_internal/commands/install.py", line 318, in run
#     resolver.resolve(requirement_set)
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_internal/resolve.py", line 102, in resolve
#     self._resolve_one(requirement_set, req)
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_internal/resolve.py", line 256, in _resolve_one
#     abstract_dist = self._get_abstract_dist_for(req_to_install)
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_internal/resolve.py", line 209, in _get_abstract_dist_for
#     self.require_hashes
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_internal/operations/prepare.py", line 298, in prepare_linked_requirement
#     abstract_dist.prep_for_dist(finder, self.build_isolation)
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_internal/operations/prepare.py", line 100, in prep_for_dist
#     self.req.load_pyproject_toml()
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_internal/req/req_install.py", line 428, in load_pyproject_toml
#     str(self)
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_internal/pyproject.py", line 43, in load_pyproject_toml
#     pp_toml = pytoml.load(f)
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_vendor/pytoml/parser.py", line 10, in load
#     return loads(fin.read(), translate=translate, object_pairs_hook=object_pairs_hook, filename=getattr(fin, 'name', repr(fin)))
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_vendor/pytoml/parser.py", line 23, in loads
#     ast = _p_toml(src, object_pairs_hook=object_pairs_hook)
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_vendor/pytoml/parser.py", line 352, in _p_toml
#     s.expect_eof()
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_vendor/pytoml/parser.py", line 124, in expect_eof
#     return self._expect(self.consume_eof())
#   File "/home/brito/.pyenv/versions/3.6.15/lib/python3.6/site-packages/pip/_vendor/pytoml/parser.py", line 164, in _expect
#     raise TomlError('msg', self._pos[0], self._pos[1], self._filename)
# pip._vendor.pytoml.core.TomlError: /tmp/pip-req-build-h5fh_tpx/pyproject.toml(9, 1): msg
# You are using pip version 18.1, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from pathlib import Path
